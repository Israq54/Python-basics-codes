# %%
class car():
  def features(self):
    self.color = 'red'
    self.model = 'toyota'
    print(self.color,self.model)
  def display(self):
    self.features()
    print(self.color,self.model)

car_obj = car()
#car_obj.features()
car_obj.display()
# Out:
# red toyota
# red toyota

# %%
class car():
  def features(self):
    self.color = 'red'
    self.model = 'toyota'
    print(self.color,self.model)
  def display(self):
    print(self.color,self.model)

car_obj = car()
car_obj.features()
car_obj.display()
# Out:
# red toyota
# red toyota

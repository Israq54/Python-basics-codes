# %% [markdown]
# # 1. Write a Python program to sum all the items in a list

# %%
list1 = [1,2,3,4,5]
x = 0
for i in range(len(list1)):
  x = list1[i] + x
print(x)
# Out:
# 15

# %% [markdown]
# # 2. Write a Python program to multiplies all the items in a list.

# %%
list1 = [2,4,8]
x = 1
for i in range(len(list1)):
  x = x*list1[i]
print(x)
# Out:
# 64

# %% [markdown]
# # 3. Write a Python program to get the largest number from a list.

# %%
list1 = [1,2,3,4,6,5,11,7]
x = 0
for i in range(len(list1)):
  if list1[i]>x:
    x = list1[i]
print('Largest Number is: ', x)
# Out:
# Largest Number is:  11

# %% [markdown]
# # 4. Write a Python program to get the smallest number from a list.

# %%
list1 = [9,3,4,6,88,9,7]
x = list1[0]
for i in range(len(list1)):
  if list1[i] < x:
    x = list1[i]
print(x)
# Out:
# 3

# %% [markdown]
# # 5. Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings.

# %%
s1 =  ['abc', 'xyz', 'aba', '1221']
count = 0
for i in range(len(s1)):
  if len(s1[i])>=2 and s1[i][0] == s1[i][-1]:
    count = count + 1
print(count)
# Out:
# 2

# %% [markdown]
# # 6. Write a Python program to get a list, sorted in increasing order by the last element in each tuple from a given list of non-empty tuples.

# %%
list1 = [(2, 5), (1, 2), (4, 4), (2, 3), (2, 1)]
list2 = []


# creating list2
for i in range(0,len(list1)):
  list2.append(list1[i][1])
list2.sort()
print('\n',list2)

# creating list1 tuples into list
for i in range(0,len(list1)):
  list1[i]=list(list1[i])
print('\n',list1,'\n')


print('_____')
# assigning values sorted
for i in range(0,len(list1)):
  list1[i][1] = list2[i]
print(list1,'\n')

print('_____')
for i in range(0,len(list1)):
  list1[i] = tuple(list1[i])
print(list1)
# Out:
#  [1, 2, 3, 4, 5]
#
#  [[2, 5], [1, 2], [4, 4], [2, 3], [2, 1]]
#
# _____
# [[2, 1], [1, 2], [4, 3], [2, 4], [2, 5]]
#
# _____
# [(2, 1), (1, 2), (4, 3), (2, 4), (2, 5)]

# %% [markdown]
# # 7. Write a Python program to remove duplicates from a list.

# %%
list1 = [1,2,2,3,4,55,55,6,7,7,7,8]
list1 = set(list1)
list1 = list(list1)
print(list1)
# Out:
# [1, 2, 3, 4, 6, 7, 8, 55]

# %% [markdown]
# # 8. Write a Python program to check a list is empty or not.

# %%
list1 = []
list2 = [1,2,3,4]
if len(list1) == 0:
  print("List1 is empty.")
else:
    print("List1 is non-empty")
if list2 == 0:
  print("list2 is empty.")
else:
    print("List2 is non empty.")
# Out:
# List1 is empty.
# List2 is non empty.

# %% [markdown]
# # 9. Write a Python program to clone or copy a list.

# %%
list1 = [1,2,3,4]
list2 = list(list1)
print(list2)
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # 10. Write a Python program to find the list of words that are longer than 4 from a given list of words.

# %%
list1 = ['israq', 'kazol', 'famim', 'orny', 'bonna']
list3 = []
for i in range(0,len(list1)):
  print(list1[i])
  if len(list1[i]) > 4:
    list3.append(list1[i])
print(list3)
# Out:
# israq
# kazol
# famim
# orny
# bonna
# ['israq', 'kazol', 'famim', 'bonna']
